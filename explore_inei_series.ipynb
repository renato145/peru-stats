# %% [markdown]
# from: http://webapp.inei.gob.pe:8080/sirtod-series/

# %% [markdown]
# # Imports & funcs

# %%
import numpy as np, pandas as pd, seaborn as sns, unidecode, math, rfpimp
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline

# %%
df = pd.read_csv('data/processed/inei_series.csv', index_col='indicador', low_memory=False)

def get_data(variables):
    df_out = (df.loc[variables].
                 dropna(axis=1, how='all').
                 set_index(['ambito', 'unidad'], append=True).
                 stack().reset_index())
    df_out.columns = ['indicador', 'departamento', 'unidad', 'y', 'value']
    df_out.y = df_out.y.astype(int)
    return df_out

def plot_var_from(df, v, cols=6, fs=(13,6), plot_avg=True, sharey=True):
    avgs = df.loc[v].groupby('y')['value'].mean().reset_index()
    df_t = df.loc[v]
    u = df_t.unidad.iloc[0]
    ys = avgs.y.unique()
    years = ys
    ys = [*ys[::3], ys[-1]]
    ysl = [f'{e}'[2:] for e in ys]
    n = df_t.departamento.nunique()
    rows =  math.ceil(n / cols)
    fig, axes = plt.subplots(rows, cols, sharey=sharey, sharex=True, figsize=(fs))
    for ax,dep in zip(axes.flatten(), df_t.departamento.unique()):
        df_dep = df_t[df_t.departamento == dep]
        if plot_avg: ax.plot(avgs.y, avgs.value, ':', color='gray')
        ax.plot(df_dep.y, df_dep.value, '-o', markersize=3, alpha=0.75)
        ax.set_title(dep)
        ax.set_xticks(ys)
        ax.set_xticklabels(ysl)
        
    for ax in axes.flatten()[len(df_t.departamento.unique()):]: ax.set_axis_off()

    # fig.suptitle(v.title().replace('_', ' '), fontsize=16, weight='bold')
    print(v.title().replace('_', ' '), f'({u}):')
    sns.despine()
    # plt.tight_layout(rect=(0, 0, 1, 0.95))
    plt.tight_layout()
    plt.show()
    print(f'Years: {", ".join(years.astype(str))}.')
    
def plot_var(v, **kwargs):
    plot_var_from(get_data(v).set_index('indicador'), v, **kwargs)
    
def plot_vars(vs, **kwargs):
    for i,e in enumerate(vs):
        plot_var(e, **kwargs)
        if i < len(vs)-1: print()

# %% [markdown]
# # Interesting vars

# %% [markdown]
# Nacimientos registrados
# Tasa bruta de natalidad total de encuesta
# Tasa de fecundidad total de 15 - 19 años
# Tasa global de fecundidad
# Tasa Total de mortalidad materna
#
# Denuncias de violencia familiar con maltrato psicológico
# Denuncias de violencia familiar por problemas conyugales y familiares
# Denuncias de violencia familiar por problemas Económicos y de trabajo
# Denuncias de violencia familiar por problemas de incompatibilidad de caracteres
# Casos registrados por el Ministerio de la Mujer y Poblaciones Vulnerables, de violencia familiar y/o sexual contra el hombre
# Casos registrados por el Ministerio de la Mujer y Poblaciones Vulnerables, de violencia familiar y/o sexual contra la mujer
# Víctimas de feminicidio por pareja o ex-pareja
# Víctimas de feminicidio por un familiar
# Víctimas de feminicidio por otra persona
#
# Total de establecimientos del Seguro Social de Salud
# Hospitales del Seguro Social de Salud (EsSALUD)
# Otros establecimientos del Seguro Social de Salud (EsSALUD)
# Evolución de casos notificados de malaria
# Casos notificados de tuberculosis
#
# Hogares que tienen al menos una computadora a nivel nacional
#
# Gasto Público por alumno en Educación Básica Alternativa
# Gasto Público por alumno en Educación Básica Especial
# Gasto Público por alumno en Educación Técnico Productiva
#
# Variables de productos:
#     Producción
#     Superficie sembrada
#     Superficie cosechada
#     Rendimiento
#     Precio en chacra
#
# Superficie cosechada de coco
# Rendimiento de coco
# Precio en chacra de coco
#
# Producción total de petróleo crudo
# Producción total de líquidos de gas natural
# Producción fiscalizada de gas natural
# Regalías cobradas por explotación de petróleo crudo
# Regalías cobradas por explotación de gas natural
# Retribuciones pagadas por explotación de petróleo crudo

# %% [markdown]
# **Tasa de fecundidad general:** Número de nacimientos con vida por cada 1.000 mujeres de edades comprendidas entre los 15 y los 49 años, en un año dado.
#
# **La tasa de mortalidad materna**: (MMRatio) es el número anual de muertes femeninas por cada 100,000 nacidos vivos por cualquier causa relacionada con o agravada por el embarazo o su manejo (excluyendo causas accidentales o incidentales). El MMRatio incluye las muertes durante el embarazo, el parto o dentro de los 42 días de la interrupción del embarazo, independientemente de la duración y el lugar del embarazo, durante un año específico.

# %%
[e for e in df.index.unique() if 'violencia' in e]
# Out:
# ['denuncias_de_violencia_familiar_con_maltrato_psicologico',
#  'denuncias_de_violencia_familiar_por_problemas_conyugales_y_familiares',
#  'denuncias_de_violencia_familiar_por_problemas_economicos_y_de_trabajo',
#  'denuncias_de_violencia_familiar_por_problemas_de_incompatibilidad_de_caracteres',
#  'casos_registrados_por_el_ministerio_de_la_mujer_y_poblaciones_vulnerables,_de_violencia_familiar_y/o_sexual_contra_el_hombre',
#  'casos_registrados_por_el_ministerio_de_la_mujer_y_poblaciones_vulnerables,_de_violencia_familiar_y/o_sexual_contra_la_mujer']

# %% [markdown]
# # fecundidad, mortalidad materna

# %%
plot_vars(['tasa_global_de_fecundidad', 'tasa_total_de_mortalidad_materna'])
# Out:
# Tasa Global De Fecundidad (Tasa):
# Years: 1996, 2000, 2006, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016.
#
# Tasa Total De Mortalidad Materna (Por 100 000 nacidos vivos):
# Years: 1996, 2000, 2007, 2009, 2010, 2011.

# %% [markdown]
# # violencia

# %%
vs = [e for e in df.index.unique() if 'violencia' in e or 'feminicidio' in e]; vs
# Out:
# ['denuncias_de_violencia_familiar_con_maltrato_psicologico',
#  'denuncias_de_violencia_familiar_por_problemas_conyugales_y_familiares',
#  'denuncias_de_violencia_familiar_por_problemas_economicos_y_de_trabajo',
#  'denuncias_de_violencia_familiar_por_problemas_de_incompatibilidad_de_caracteres',
#  'casos_registrados_por_el_ministerio_de_la_mujer_y_poblaciones_vulnerables,_de_violencia_familiar_y/o_sexual_contra_el_hombre',
#  'casos_registrados_por_el_ministerio_de_la_mujer_y_poblaciones_vulnerables,_de_violencia_familiar_y/o_sexual_contra_la_mujer',
#  'victimas_de_feminicidio_por_pareja_o_ex-pareja',
#  'victimas_de_feminicidio_por_un_familiar',
#  'victimas_de_feminicidio_por_otra_persona']

# %%
plot_vars(vs, cols=5, plot_avg=False, sharey=False)
# Out:
# Denuncias De Violencia Familiar Con Maltrato Psicologico (Casos registrados):
# Years: 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016.
#
# Denuncias De Violencia Familiar Por Problemas Conyugales Y Familiares (Casos registrados):
# Years: 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016.
#
# Denuncias De Violencia Familiar Por Problemas Economicos Y De Trabajo (Casos registrados):
# Years: 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016.
#
# Denuncias De Violencia Familiar Por Problemas De Incompatibilidad De Caracteres (Casos registrados):
# Years: 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016.
#
# Casos Registrados Por El Ministerio De La Mujer Y Poblaciones Vulnerables, De Violencia Familiar Y/O Sexual Contra El Hombre (Casos registrados):
# Years: 2009, 2010, 2011, 2012, 2013, 2014, 2015.
#
# Casos Registrados Por El Ministerio De La Mujer Y Poblaciones Vulnerables, De Violencia Familiar Y/O Sexual Contra La Mujer (Casos registrados):
# Years: 2009, 2010, 2011, 2012, 2013, 2014, 2015.
#
# Victimas De Feminicidio Por Pareja O Ex-Pareja (Casos registrados):
# Years: 2009, 2010, 2011, 2012, 2013.
#
# Victimas De Feminicidio Por Un Familiar (Casos registrados):
# Years: 2009, 2010, 2011, 2012, 2013.
#
# Victimas De Feminicidio Por Otra Persona (Casos registrados):
# Years: 2009, 2010, 2011, 2012, 2013.

# %%
dff = df.reset_index()

# %%
dff.indicador.nunique()
# Out:
# 491

# %%
dff.indicador[~dff.indicador.str.contains(r'produccion|precio|sueldo|superficie|rendimiento')].nunique()
# Out:
# 181

# %%
df = df.reset_index()

# %%
dff = (df[~df.indicador.str.contains(r'produccion|precio|sueldo|superficie|rendimiento|poblacion|ministerio|nacimientos')].
       drop_duplicates(['ambito', 'indicador']).
       drop('unidad', axis=1).
       set_index(['ambito', 'indicador']).
       unstack().
       dropna(axis=1, how='all'))
dff.shape
# Out:
# (25, 1425)

# %%
aa = dff.loc[:,['2016']]
sns.heatmap(aa.corr())

# %%
a = rfpimp.feature_corr_matrix(dff.loc[:,['2016']])

plt.figure(figsize=(12,12))
sns.heatmap(a)

# %%
a.loc['2016', '2016']
# Out:
# indicador                                           clientes_del_suministro_de_energia_electrica_en_el_mercado_libre  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                             1.0000
# clientes_del_suministro_de_energia_electrica_en...                                             0.0335
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             0.1278
# defunciones_de_hombres_registradas                                                             0.0539
# defunciones_de_hombres_registradas_por_parte_po...                                             0.1831
# defunciones_de_hombres_registradas_por_via_ordi...                                             0.0400
# defunciones_de_hombres_registrados_por_via_judi...                                            -0.2404
# defunciones_de_mujeres_registradas                                                             0.0554
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.5434
# defunciones_de_mujeres_registradas_por_via_judi...                                            -0.2404
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.0501
# defunciones_registradas                                                                        0.0504
# defunciones_registradas_por_parte_policial                                                     0.1578
# defunciones_registradas_por_via_judicial                                                      -0.1529
# defunciones_registradas_por_via_ordinaria                                                      0.0689
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.0335
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.2449
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.0046
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.0166
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.0266
# denuncias_de_violencia_familiar_por_problemas_d...                                            -0.1710
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.2538
# denuncias_registradas_por_robo_de_vehiculos                                                    0.4721
# droga_decomisada                                                                               0.2303
# evolucion_de_casos_notificados_de_malaria                                                     -0.0922
# extraccion_de_trucha_(fresco)                                                                  0.4621
# fiscalia_de_la_nacion_del_ministerio_publico                                                   0.0693
# fiscalia_provincial_del_ministerio_publico                                                    -0.0491
# fiscalias_superiores_del_ministerio_publico                                                    0.0556
# fiscalias_supremas_del_ministerio_publico                                                      0.0693
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                 0.1945
# rendimiento_de_haba_grano_verde                                                                0.5160
# rendimiento_de_kiwicha                                                                         0.5699
# rendimiento_de_lenteja                                                                         0.6565
# rendimiento_de_maiz_amarillo_duro                                                              0.3962
# rendimiento_de_maiz_amilaceo                                                                   0.3535
# rendimiento_de_maiz_choclo                                                                     0.1271
# rendimiento_de_oca                                                                             0.1217
# rendimiento_de_olluco                                                                          0.2056
# rendimiento_de_pallar_grano_seco                                                               0.4205
# rendimiento_de_papa                                                                            0.4532
# rendimiento_de_quinua                                                                          0.3866
# rendimiento_de_sorgo_grano                                                                     0.1740
# rendimiento_de_soya                                                                            0.0986
# rendimiento_de_tarhui                                                                          0.4039
# rendimiento_de_tomate                                                                         -0.1429
# rendimiento_de_trigo                                                                           0.3649
# rendimiento_de_yuca                                                                           -0.0058
# rendimiento_de_zarandaja                                                                       0.3342
# tasa_bruta_de_natalidad_total_de_encuesta                                                     -0.1598
# tasa_de_actividad_femenina                                                                    -0.3847
# tasa_de_actividad_masculina                                                                    0.1952
# tasa_global_de_fecundidad                                                                      0.5242
# total_de_creditos_directos_de_la_banca_multiple                                                0.1267
# total_de_creditos_directos_de_las_cajas_municip...                                            -0.1756
# total_de_creditos_directos_de_las_cajas_rurales                                                0.0893
# total_de_creditos_directos_de_las_entidades_de_...                                             0.4609
# total_de_depositos_de_la_banca_multiple                                                        0.0735
# total_de_depositos_de_las_cajas_municipales                                                   -0.1690
# total_de_depositos_de_las_cajas_rurales                                                        0.2233
#
# indicador                                           clientes_del_suministro_de_energia_electrica_en_el_mercado_regulado  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                             0.0335
# clientes_del_suministro_de_energia_electrica_en...                                             1.0000
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             0.8985
# defunciones_de_hombres_registradas                                                             0.9200
# defunciones_de_hombres_registradas_por_parte_po...                                             0.4670
# defunciones_de_hombres_registradas_por_via_ordi...                                             0.8962
# defunciones_de_hombres_registrados_por_via_judi...                                             0.4660
# defunciones_de_mujeres_registradas                                                             0.9192
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.3186
# defunciones_de_mujeres_registradas_por_via_judi...                                             0.4660
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.9177
# defunciones_registradas                                                                        0.9223
# defunciones_registradas_por_parte_policial                                                     0.4661
# defunciones_registradas_por_via_judicial                                                       0.4562
# defunciones_registradas_por_via_ordinaria                                                      0.9123
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7345
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.8123
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.8617
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.7654
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.8446
# denuncias_de_violencia_familiar_por_problemas_d...                                             0.8138
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.6462
# denuncias_registradas_por_robo_de_vehiculos                                                    0.4177
# droga_decomisada                                                                               0.4615
# evolucion_de_casos_notificados_de_malaria                                                     -0.0650
# extraccion_de_trucha_(fresco)                                                                 -0.0915
# fiscalia_de_la_nacion_del_ministerio_publico                                                   0.1438
# fiscalia_provincial_del_ministerio_publico                                                     0.6817
# fiscalias_superiores_del_ministerio_publico                                                    0.8011
# fiscalias_supremas_del_ministerio_publico                                                      0.1438
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                -0.1008
# rendimiento_de_haba_grano_verde                                                                0.0254
# rendimiento_de_kiwicha                                                                        -0.0654
# rendimiento_de_lenteja                                                                         0.1631
# rendimiento_de_maiz_amarillo_duro                                                              0.5369
# rendimiento_de_maiz_amilaceo                                                                   0.0477
# rendimiento_de_maiz_choclo                                                                     0.1023
# rendimiento_de_oca                                                                            -0.4477
# rendimiento_de_olluco                                                                         -0.4754
# rendimiento_de_pallar_grano_seco                                                               0.0323
# rendimiento_de_papa                                                                           -0.1077
# rendimiento_de_quinua                                                                          0.1754
# rendimiento_de_sorgo_grano                                                                    -0.1808
# rendimiento_de_soya                                                                            0.1369
# rendimiento_de_tarhui                                                                         -0.1169
# rendimiento_de_tomate                                                                          0.3746
# rendimiento_de_trigo                                                                          -0.0073
# rendimiento_de_yuca                                                                           -0.1715
# rendimiento_de_zarandaja                                                                      -0.1631
# tasa_bruta_de_natalidad_total_de_encuesta                                                     -0.2139
# tasa_de_actividad_femenina                                                                    -0.1992
# tasa_de_actividad_masculina                                                                   -0.5954
# tasa_global_de_fecundidad                                                                     -0.3569
# total_de_creditos_directos_de_la_banca_multiple                                                0.9015
# total_de_creditos_directos_de_las_cajas_municip...                                             0.6808
# total_de_creditos_directos_de_las_cajas_rurales                                               -0.3577
# total_de_creditos_directos_de_las_entidades_de_...                                             0.5062
# total_de_depositos_de_la_banca_multiple                                                        0.8877
# total_de_depositos_de_las_cajas_municipales                                                    0.7685
# total_de_depositos_de_las_cajas_rurales                                                       -0.4485
#
# indicador                                           conexiones_de_tv_de_paga_digital_y_numero_de_altas  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                             0.1278
# clientes_del_suministro_de_energia_electrica_en...                                             0.8985
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             1.0000
# defunciones_de_hombres_registradas                                                             0.8469
# defunciones_de_hombres_registradas_por_parte_po...                                             0.4520
# defunciones_de_hombres_registradas_por_via_ordi...                                             0.8262
# defunciones_de_hombres_registrados_por_via_judi...                                             0.4283
# defunciones_de_mujeres_registradas                                                             0.8400
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.4141
# defunciones_de_mujeres_registradas_por_via_judi...                                             0.4283
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.8354
# defunciones_registradas                                                                        0.8554
# defunciones_registradas_por_parte_policial                                                     0.4450
# defunciones_registradas_por_via_judicial                                                       0.4312
# defunciones_registradas_por_via_ordinaria                                                      0.8323
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7314
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7800
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.8625
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.8554
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.7908
# denuncias_de_violencia_familiar_por_problemas_d...                                             0.7862
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.6515
# denuncias_registradas_por_robo_de_vehiculos                                                    0.4500
# droga_decomisada                                                                               0.3646
# evolucion_de_casos_notificados_de_malaria                                                     -0.0265
# extraccion_de_trucha_(fresco)                                                                 -0.0362
# fiscalia_de_la_nacion_del_ministerio_publico                                                   0.0938
# fiscalia_provincial_del_ministerio_publico                                                     0.5262
# fiscalias_superiores_del_ministerio_publico                                                    0.7662
# fiscalias_supremas_del_ministerio_publico                                                      0.0938
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                 0.0162
# rendimiento_de_haba_grano_verde                                                                0.0508
# rendimiento_de_kiwicha                                                                        -0.0177
# rendimiento_de_lenteja                                                                         0.2515
# rendimiento_de_maiz_amarillo_duro                                                              0.7092
# rendimiento_de_maiz_amilaceo                                                                   0.1631
# rendimiento_de_maiz_choclo                                                                     0.1915
# rendimiento_de_oca                                                                            -0.4354
# rendimiento_de_olluco                                                                         -0.4715
# rendimiento_de_pallar_grano_seco                                                              -0.0877
# rendimiento_de_papa                                                                           -0.0185
# rendimiento_de_quinua                                                                          0.2900
# rendimiento_de_sorgo_grano                                                                    -0.2377
# rendimiento_de_soya                                                                            0.1892
# rendimiento_de_tarhui                                                                          0.0908
# rendimiento_de_tomate                                                                          0.4415
# rendimiento_de_trigo                                                                           0.0415
# rendimiento_de_yuca                                                                            0.0138
# rendimiento_de_zarandaja                                                                      -0.1623
# tasa_bruta_de_natalidad_total_de_encuesta                                                     -0.4678
# tasa_de_actividad_femenina                                                                    -0.3985
# tasa_de_actividad_masculina                                                                   -0.7200
# tasa_global_de_fecundidad                                                                     -0.4005
# total_de_creditos_directos_de_la_banca_multiple                                                0.9731
# total_de_creditos_directos_de_las_cajas_municip...                                             0.6408
# total_de_creditos_directos_de_las_cajas_rurales                                               -0.1915
# total_de_creditos_directos_de_las_entidades_de_...                                             0.4985
# total_de_depositos_de_la_banca_multiple                                                        0.9731
# total_de_depositos_de_las_cajas_municipales                                                    0.8162
# total_de_depositos_de_las_cajas_rurales                                                       -0.2746
#
# indicador                                           defunciones_de_hombres_registradas  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                              0.0539
# clientes_del_suministro_de_energia_electrica_en...                              0.9200
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                              0.8469
# defunciones_de_hombres_registradas                                              1.0000
# defunciones_de_hombres_registradas_por_parte_po...                              0.3804
# defunciones_de_hombres_registradas_por_via_ordi...                              0.9954
# defunciones_de_hombres_registrados_por_via_judi...                              0.5862
# defunciones_de_mujeres_registradas                                              0.9915
# defunciones_de_mujeres_registradas_por_parte_po...                              0.3444
# defunciones_de_mujeres_registradas_por_via_judi...                              0.5862
# defunciones_de_mujeres_registradas_por_via_ordi...                              0.9923
# defunciones_registradas                                                         0.9954
# defunciones_registradas_por_parte_policial                                      0.3876
# defunciones_registradas_por_via_judicial                                        0.5913
# defunciones_registradas_por_via_ordinaria                                       0.9977
# denuncias_de_accidentes_de_transito_no_fatales_...                              0.7334
# denuncias_de_accidentes_de_transito_no_fatales_...                              0.7446
# denuncias_de_accidentes_de_transito_no_fatales_...                              0.7709
# denuncias_de_violencia_familiar_con_maltrato_ps...                              0.7169
# denuncias_de_violencia_familiar_por_problemas_c...                              0.8508
# denuncias_de_violencia_familiar_por_problemas_d...                              0.7108
# denuncias_de_violencia_familiar_por_problemas_e...                              0.5969
# denuncias_registradas_por_robo_de_vehiculos                                     0.4885
# droga_decomisada                                                                0.3915
# evolucion_de_casos_notificados_de_malaria                                      -0.1831
# extraccion_de_trucha_(fresco)                                                  -0.0900
# fiscalia_de_la_nacion_del_ministerio_publico                                    0.0562
# fiscalia_provincial_del_ministerio_publico                                      0.7229
# fiscalias_superiores_del_ministerio_publico                                     0.7498
# fiscalias_supremas_del_ministerio_publico                                       0.0562
# ...                                                                                ...
# rendimiento_de_haba_grano_seco                                                 -0.2446
# rendimiento_de_haba_grano_verde                                                -0.0138
# rendimiento_de_kiwicha                                                         -0.1077
# rendimiento_de_lenteja                                                          0.1408
# rendimiento_de_maiz_amarillo_duro                                               0.4262
# rendimiento_de_maiz_amilaceo                                                   -0.0546
# rendimiento_de_maiz_choclo                                                     -0.0162
# rendimiento_de_oca                                                             -0.5231
# rendimiento_de_olluco                                                          -0.5738
# rendimiento_de_pallar_grano_seco                                               -0.0208
# rendimiento_de_papa                                                            -0.2362
# rendimiento_de_quinua                                                           0.0554
# rendimiento_de_sorgo_grano                                                     -0.2215
# rendimiento_de_soya                                                            -0.0208
# rendimiento_de_tarhui                                                          -0.2077
# rendimiento_de_tomate                                                           0.3269
# rendimiento_de_trigo                                                           -0.1496
# rendimiento_de_yuca                                                            -0.3292
# rendimiento_de_zarandaja                                                       -0.2123
# tasa_bruta_de_natalidad_total_de_encuesta                                      -0.1046
# tasa_de_actividad_femenina                                                     -0.1562
# tasa_de_actividad_masculina                                                    -0.5677
# tasa_global_de_fecundidad                                                      -0.4002
# total_de_creditos_directos_de_la_banca_multiple                                 0.8638
# total_de_creditos_directos_de_las_cajas_municip...                              0.7823
# total_de_creditos_directos_de_las_cajas_rurales                                -0.2685
# total_de_creditos_directos_de_las_entidades_de_...                              0.5608
# total_de_depositos_de_la_banca_multiple                                         0.8469
# total_de_depositos_de_las_cajas_municipales                                     0.8115
# total_de_depositos_de_las_cajas_rurales                                        -0.3292
#
# indicador                                           defunciones_de_hombres_registradas_por_parte_policial  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                             0.1831
# clientes_del_suministro_de_energia_electrica_en...                                             0.4670
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             0.4520
# defunciones_de_hombres_registradas                                                             0.3804
# defunciones_de_hombres_registradas_por_parte_po...                                             1.0000
# defunciones_de_hombres_registradas_por_via_ordi...                                             0.3511
# defunciones_de_hombres_registrados_por_via_judi...                                             0.0742
# defunciones_de_mujeres_registradas                                                             0.3831
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.5404
# defunciones_de_mujeres_registradas_por_via_judi...                                             0.0742
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.3769
# defunciones_registradas                                                                        0.3892
# defunciones_registradas_por_parte_policial                                                     0.9805
# defunciones_registradas_por_via_judicial                                                       0.1371
# defunciones_registradas_por_via_ordinaria                                                      0.3580
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.5009
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.5559
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.5356
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.5975
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.4058
# denuncias_de_violencia_familiar_por_problemas_d...                                             0.5051
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.5340
# denuncias_registradas_por_robo_de_vehiculos                                                    0.3630
# droga_decomisada                                                                               0.1952
# evolucion_de_casos_notificados_de_malaria                                                     -0.0250
# extraccion_de_trucha_(fresco)                                                                 -0.1705
# fiscalia_de_la_nacion_del_ministerio_publico                                                  -0.0835
# fiscalia_provincial_del_ministerio_publico                                                     0.2510
# fiscalias_superiores_del_ministerio_publico                                                    0.4058
# fiscalias_supremas_del_ministerio_publico                                                     -0.0835
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                 0.2672
# rendimiento_de_haba_grano_verde                                                                0.2356
# rendimiento_de_kiwicha                                                                         0.0004
# rendimiento_de_lenteja                                                                         0.0493
# rendimiento_de_maiz_amarillo_duro                                                              0.4293
# rendimiento_de_maiz_amilaceo                                                                   0.2737
# rendimiento_de_maiz_choclo                                                                     0.2464
# rendimiento_de_oca                                                                            -0.1421
# rendimiento_de_olluco                                                                         -0.1763
# rendimiento_de_pallar_grano_seco                                                              -0.1140
# rendimiento_de_papa                                                                            0.2464
# rendimiento_de_quinua                                                                          0.2017
# rendimiento_de_sorgo_grano                                                                    -0.2268
# rendimiento_de_soya                                                                            0.1682
# rendimiento_de_tarhui                                                                          0.1270
# rendimiento_de_tomate                                                                          0.3403
# rendimiento_de_trigo                                                                           0.2074
# rendimiento_de_yuca                                                                            0.1794
# rendimiento_de_zarandaja                                                                      -0.0485
# tasa_bruta_de_natalidad_total_de_encuesta                                                     -0.3229
# tasa_de_actividad_femenina                                                                    -0.2406
# tasa_de_actividad_masculina                                                                   -0.3145
# tasa_global_de_fecundidad                                                                     -0.1659
# total_de_creditos_directos_de_la_banca_multiple                                                0.4701
# total_de_creditos_directos_de_las_cajas_municip...                                             0.4073
# total_de_creditos_directos_de_las_cajas_rurales                                               -0.2876
# total_de_creditos_directos_de_las_entidades_de_...                                             0.4142
# total_de_depositos_de_la_banca_multiple                                                        0.4551
# total_de_depositos_de_las_cajas_municipales                                                    0.4362
# total_de_depositos_de_las_cajas_rurales                                                       -0.4039
#
# indicador                                           defunciones_de_hombres_registradas_por_via_ordinaria  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                             0.0400
# clientes_del_suministro_de_energia_electrica_en...                                             0.8962
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             0.8262
# defunciones_de_hombres_registradas                                                             0.9954
# defunciones_de_hombres_registradas_por_parte_po...                                             0.3511
# defunciones_de_hombres_registradas_por_via_ordi...                                             1.0000
# defunciones_de_hombres_registrados_por_via_judi...                                             0.5862
# defunciones_de_mujeres_registradas                                                             0.9846
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.3356
# defunciones_de_mujeres_registradas_por_via_judi...                                             0.5862
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.9869
# defunciones_registradas                                                                        0.9892
# defunciones_registradas_por_parte_policial                                                     0.3580
# defunciones_registradas_por_via_judicial                                                       0.5928
# defunciones_registradas_por_via_ordinaria                                                      0.9954
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7195
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7192
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.7401
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.7062
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.8446
# denuncias_de_violencia_familiar_por_problemas_d...                                             0.6931
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.5723
# denuncias_registradas_por_robo_de_vehiculos                                                    0.5200
# droga_decomisada                                                                               0.3777
# evolucion_de_casos_notificados_de_malaria                                                     -0.1793
# extraccion_de_trucha_(fresco)                                                                 -0.0754
# fiscalia_de_la_nacion_del_ministerio_publico                                                   0.0415
# fiscalia_provincial_del_ministerio_publico                                                     0.7159
# fiscalias_superiores_del_ministerio_publico                                                    0.7417
# fiscalias_supremas_del_ministerio_publico                                                      0.0415
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                -0.2554
# rendimiento_de_haba_grano_verde                                                               -0.0354
# rendimiento_de_kiwicha                                                                        -0.1046
# rendimiento_de_lenteja                                                                         0.1231
# rendimiento_de_maiz_amarillo_duro                                                              0.4077
# rendimiento_de_maiz_amilaceo                                                                  -0.0631
# rendimiento_de_maiz_choclo                                                                    -0.0515
# rendimiento_de_oca                                                                            -0.5315
# rendimiento_de_olluco                                                                         -0.5846
# rendimiento_de_pallar_grano_seco                                                              -0.0315
# rendimiento_de_papa                                                                           -0.2569
# rendimiento_de_quinua                                                                          0.0369
# rendimiento_de_sorgo_grano                                                                    -0.2146
# rendimiento_de_soya                                                                           -0.0438
# rendimiento_de_tarhui                                                                         -0.2092
# rendimiento_de_tomate                                                                          0.2946
# rendimiento_de_trigo                                                                          -0.1673
# rendimiento_de_yuca                                                                           -0.3592
# rendimiento_de_zarandaja                                                                      -0.2415
# tasa_bruta_de_natalidad_total_de_encuesta                                                     -0.0700
# tasa_de_actividad_femenina                                                                    -0.1531
# tasa_de_actividad_masculina                                                                   -0.5523
# tasa_global_de_fecundidad                                                                     -0.4013
# total_de_creditos_directos_de_la_banca_multiple                                                0.8454
# total_de_creditos_directos_de_las_cajas_municip...                                             0.7923
# total_de_creditos_directos_de_las_cajas_rurales                                               -0.2454
# total_de_creditos_directos_de_las_entidades_de_...                                             0.5823
# total_de_depositos_de_la_banca_multiple                                                        0.8246
# total_de_depositos_de_las_cajas_municipales                                                    0.8162
# total_de_depositos_de_las_cajas_rurales                                                       -0.3015
#
# indicador                                           defunciones_de_hombres_registrados_por_via_judicial  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                            -0.2404
# clientes_del_suministro_de_energia_electrica_en...                                             0.4660
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                             0.4283
# defunciones_de_hombres_registradas                                                             0.5862
# defunciones_de_hombres_registradas_por_parte_po...                                             0.0742
# defunciones_de_hombres_registradas_por_via_ordi...                                             0.5862
# defunciones_de_hombres_registrados_por_via_judi...                                             1.0000
# defunciones_de_mujeres_registradas                                                             0.5931
# defunciones_de_mujeres_registradas_por_parte_po...                                             0.2083
# defunciones_de_mujeres_registradas_por_via_judi...                                             1.0000
# defunciones_de_mujeres_registradas_por_via_ordi...                                             0.5885
# defunciones_registradas                                                                        0.5916
# defunciones_registradas_por_parte_policial                                                     0.0592
# defunciones_registradas_por_via_judicial                                                       0.9807
# defunciones_registradas_por_via_ordinaria                                                      0.5685
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.3697
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.2238
# denuncias_de_accidentes_de_transito_no_fatales_...                                             0.3529
# denuncias_de_violencia_familiar_con_maltrato_ps...                                             0.3285
# denuncias_de_violencia_familiar_por_problemas_c...                                             0.5030
# denuncias_de_violencia_familiar_por_problemas_d...                                             0.4379
# denuncias_de_violencia_familiar_por_problemas_e...                                             0.1232
# denuncias_registradas_por_robo_de_vehiculos                                                    0.3424
# droga_decomisada                                                                               0.2958
# evolucion_de_casos_notificados_de_malaria                                                     -0.1225
# extraccion_de_trucha_(fresco)                                                                 -0.0894
# fiscalia_de_la_nacion_del_ministerio_publico                                                   0.1390
# fiscalia_provincial_del_ministerio_publico                                                     0.4997
# fiscalias_superiores_del_ministerio_publico                                                    0.3924
# fiscalias_supremas_del_ministerio_publico                                                      0.1390
# ...                                                                                               ...
# rendimiento_de_haba_grano_seco                                                                -0.0870
# rendimiento_de_haba_grano_verde                                                               -0.0589
# rendimiento_de_kiwicha                                                                        -0.0246
# rendimiento_de_lenteja                                                                        -0.0212
# rendimiento_de_maiz_amarillo_duro                                                              0.0397
# rendimiento_de_maiz_amilaceo                                                                  -0.1567
# rendimiento_de_maiz_choclo                                                                    -0.1956
# rendimiento_de_oca                                                                            -0.3986
# rendimiento_de_olluco                                                                         -0.4953
# rendimiento_de_pallar_grano_seco                                                              -0.0393
# rendimiento_de_papa                                                                           -0.1995
# rendimiento_de_quinua                                                                         -0.0712
# rendimiento_de_sorgo_grano                                                                    -0.1028
# rendimiento_de_soya                                                                           -0.1814
# rendimiento_de_tarhui                                                                         -0.2272
# rendimiento_de_tomate                                                                          0.0062
# rendimiento_de_trigo                                                                          -0.1204
# rendimiento_de_yuca                                                                           -0.3116
# rendimiento_de_zarandaja                                                                       0.0085
# tasa_bruta_de_natalidad_total_de_encuesta                                                      0.0514
# tasa_de_actividad_femenina                                                                     0.1036
# tasa_de_actividad_masculina                                                                   -0.4244
# tasa_global_de_fecundidad                                                                     -0.4657
# total_de_creditos_directos_de_la_banca_multiple                                                0.4233
# total_de_creditos_directos_de_las_cajas_municip...                                             0.6224
# total_de_creditos_directos_de_las_cajas_rurales                                                0.1317
# total_de_creditos_directos_de_las_entidades_de_...                                             0.0166
# total_de_depositos_de_la_banca_multiple                                                        0.4545
# total_de_depositos_de_las_cajas_municipales                                                    0.5827
# ...
# denuncias_de_violencia_familiar_por_problemas_e...                                   0.6877
# denuncias_registradas_por_robo_de_vehiculos                                          0.4023
# droga_decomisada                                                                     0.3962
# evolucion_de_casos_notificados_de_malaria                                           -0.0177
# extraccion_de_trucha_(fresco)                                                       -0.0192
# fiscalia_de_la_nacion_del_ministerio_publico                                         0.0769
# fiscalia_provincial_del_ministerio_publico                                           0.4681
# fiscalias_superiores_del_ministerio_publico                                          0.7312
# fiscalias_supremas_del_ministerio_publico                                            0.0769
# ...                                                                                     ...
# rendimiento_de_haba_grano_seco                                                       0.0292
# rendimiento_de_haba_grano_verde                                                      0.0615
# rendimiento_de_kiwicha                                                              -0.0046
# rendimiento_de_lenteja                                                               0.2938
# rendimiento_de_maiz_amarillo_duro                                                    0.6777
# rendimiento_de_maiz_amilaceo                                                         0.1554
# rendimiento_de_maiz_choclo                                                           0.2285
# rendimiento_de_oca                                                                  -0.4262
# rendimiento_de_olluco                                                               -0.4631
# rendimiento_de_pallar_grano_seco                                                    -0.0500
# rendimiento_de_papa                                                                 -0.0369
# rendimiento_de_quinua                                                                0.2169
# rendimiento_de_sorgo_grano                                                          -0.2692
# rendimiento_de_soya                                                                  0.1408
# rendimiento_de_tarhui                                                                0.0915
# rendimiento_de_tomate                                                                0.5069
# rendimiento_de_trigo                                                                 0.0385
# rendimiento_de_yuca                                                                  0.0300
# rendimiento_de_zarandaja                                                            -0.1592
# tasa_bruta_de_natalidad_total_de_encuesta                                           -0.5197
# tasa_de_actividad_femenina                                                          -0.3685
# tasa_de_actividad_masculina                                                         -0.7523
# tasa_global_de_fecundidad                                                           -0.4600
# total_de_creditos_directos_de_la_banca_multiple                                      0.9723
# total_de_creditos_directos_de_las_cajas_municip...                                   0.6792
# total_de_creditos_directos_de_las_cajas_rurales                                     -0.1631
# total_de_creditos_directos_de_las_entidades_de_...                                   0.4531
# total_de_depositos_de_la_banca_multiple                                              1.0000
# total_de_depositos_de_las_cajas_municipales                                          0.8523
# total_de_depositos_de_las_cajas_rurales                                             -0.2685
#
# indicador                                           total_de_depositos_de_las_cajas_municipales  \
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                      -0.1690
# clientes_del_suministro_de_energia_electrica_en...                                       0.7685
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                       0.8162
# defunciones_de_hombres_registradas                                                       0.8115
# defunciones_de_hombres_registradas_por_parte_po...                                       0.4362
# defunciones_de_hombres_registradas_por_via_ordi...                                       0.8162
# defunciones_de_hombres_registrados_por_via_judi...                                       0.5827
# defunciones_de_mujeres_registradas                                                       0.7977
# defunciones_de_mujeres_registradas_por_parte_po...                                       0.2290
# defunciones_de_mujeres_registradas_por_via_judi...                                       0.5827
# defunciones_de_mujeres_registradas_por_via_ordi...                                       0.7962
# defunciones_registradas                                                                  0.8162
# defunciones_registradas_por_parte_policial                                               0.4292
# defunciones_registradas_por_via_judicial                                                 0.5740
# defunciones_registradas_por_via_ordinaria                                                0.7915
# denuncias_de_accidentes_de_transito_no_fatales_...                                       0.7695
# denuncias_de_accidentes_de_transito_no_fatales_...                                       0.7031
# denuncias_de_accidentes_de_transito_no_fatales_...                                       0.7748
# denuncias_de_violencia_familiar_con_maltrato_ps...                                       0.8777
# denuncias_de_violencia_familiar_por_problemas_c...                                       0.8585
# denuncias_de_violencia_familiar_por_problemas_d...                                       0.8315
# denuncias_de_violencia_familiar_por_problemas_e...                                       0.6638
# denuncias_registradas_por_robo_de_vehiculos                                              0.3654
# droga_decomisada                                                                         0.2231
# evolucion_de_casos_notificados_de_malaria                                               -0.0404
# extraccion_de_trucha_(fresco)                                                           -0.2062
# fiscalia_de_la_nacion_del_ministerio_publico                                            -0.0769
# fiscalia_provincial_del_ministerio_publico                                               0.4573
# fiscalias_superiores_del_ministerio_publico                                              0.5964
# fiscalias_supremas_del_ministerio_publico                                               -0.0769
# ...                                                                                         ...
# rendimiento_de_haba_grano_seco                                                          -0.0846
# rendimiento_de_haba_grano_verde                                                         -0.0692
# rendimiento_de_kiwicha                                                                  -0.2023
# rendimiento_de_lenteja                                                                   0.0862
# rendimiento_de_maiz_amarillo_duro                                                        0.4723
# rendimiento_de_maiz_amilaceo                                                             0.0015
# rendimiento_de_maiz_choclo                                                              -0.0038
# rendimiento_de_oca                                                                      -0.5162
# rendimiento_de_olluco                                                                   -0.5800
# rendimiento_de_pallar_grano_seco                                                        -0.2215
# rendimiento_de_papa                                                                     -0.2023
# rendimiento_de_quinua                                                                    0.0908
# rendimiento_de_sorgo_grano                                                              -0.4254
# rendimiento_de_soya                                                                     -0.0131
# rendimiento_de_tarhui                                                                   -0.0877
# rendimiento_de_tomate                                                                    0.3492
# rendimiento_de_trigo                                                                    -0.0739
# rendimiento_de_yuca                                                                     -0.1385
# rendimiento_de_zarandaja                                                                -0.3254
# tasa_bruta_de_natalidad_total_de_encuesta                                               -0.3162
# tasa_de_actividad_femenina                                                              -0.2762
# tasa_de_actividad_masculina                                                             -0.7231
# tasa_global_de_fecundidad                                                               -0.6756
# total_de_creditos_directos_de_la_banca_multiple                                          0.8185
# total_de_creditos_directos_de_las_cajas_municip...                                       0.9131
# total_de_creditos_directos_de_las_cajas_rurales                                         -0.1523
# total_de_creditos_directos_de_las_entidades_de_...                                       0.4377
# total_de_depositos_de_la_banca_multiple                                                  0.8523
# total_de_depositos_de_las_cajas_municipales                                              1.0000
# total_de_depositos_de_las_cajas_rurales                                                 -0.2915
#
# indicador                                           total_de_depositos_de_las_cajas_rurales
# indicador
# clientes_del_suministro_de_energia_electrica_en...                                   0.2233
# clientes_del_suministro_de_energia_electrica_en...                                  -0.4485
# conexiones_de_tv_de_paga_digital_y_numero_de_altas                                  -0.2746
# defunciones_de_hombres_registradas                                                  -0.3292
# defunciones_de_hombres_registradas_por_parte_po...                                  -0.4039
# defunciones_de_hombres_registradas_por_via_ordi...                                  -0.3015
# defunciones_de_hombres_registrados_por_via_judi...                                  -0.0108
# defunciones_de_mujeres_registradas                                                  -0.2938
# defunciones_de_mujeres_registradas_por_parte_po...                                   0.0962
# defunciones_de_mujeres_registradas_por_via_judi...                                  -0.0108
# defunciones_de_mujeres_registradas_por_via_ordi...                                  -0.2985
# defunciones_registradas                                                             -0.3046
# defunciones_registradas_por_parte_policial                                          -0.3730
# defunciones_registradas_por_via_judicial                                             0.0065
# defunciones_registradas_por_via_ordinaria                                           -0.3062
# denuncias_de_accidentes_de_transito_no_fatales_...                                  -0.3940
# denuncias_de_accidentes_de_transito_no_fatales_...                                  -0.3408
# denuncias_de_accidentes_de_transito_no_fatales_...                                  -0.5120
# denuncias_de_violencia_familiar_con_maltrato_ps...                                  -0.4054
# denuncias_de_violencia_familiar_por_problemas_c...                                  -0.2908
# denuncias_de_violencia_familiar_por_problemas_d...                                  -0.5000
# denuncias_de_violencia_familiar_por_problemas_e...                                  -0.1677
# denuncias_registradas_por_robo_de_vehiculos                                          0.0769
# droga_decomisada                                                                    -0.2223
# evolucion_de_casos_notificados_de_malaria                                            0.0104
# extraccion_de_trucha_(fresco)                                                        0.2908
# fiscalia_de_la_nacion_del_ministerio_publico                                        -0.1408
# fiscalia_provincial_del_ministerio_publico                                          -0.4238
# fiscalias_superiores_del_ministerio_publico                                         -0.3213
# fiscalias_supremas_del_ministerio_publico                                           -0.1408
# ...                                                                                     ...
# rendimiento_de_haba_grano_seco                                                       0.0469
# rendimiento_de_haba_grano_verde                                                     -0.0754
# rendimiento_de_kiwicha                                                               0.3138
# rendimiento_de_lenteja                                                               0.2392
# rendimiento_de_maiz_amarillo_duro                                                   -0.0146
# rendimiento_de_maiz_amilaceo                                                        -0.0800
# rendimiento_de_maiz_choclo                                                           0.0869
# rendimiento_de_oca                                                                   0.0185
# rendimiento_de_olluco                                                                0.0054
# rendimiento_de_pallar_grano_seco                                                     0.2292
# rendimiento_de_papa                                                                 -0.0223
# rendimiento_de_quinua                                                               -0.2815
# rendimiento_de_sorgo_grano                                                          -0.1123
# rendimiento_de_soya                                                                  0.1762
# rendimiento_de_tarhui                                                                0.1462
# rendimiento_de_tomate                                                               -0.0738
# rendimiento_de_trigo                                                                -0.0916
# rendimiento_de_yuca                                                                  0.2708
# rendimiento_de_zarandaja                                                            -0.0569
# tasa_bruta_de_natalidad_total_de_encuesta                                            0.0389
# tasa_de_actividad_femenina                                                           0.0923
# tasa_de_actividad_masculina                                                          0.1569
# tasa_global_de_fecundidad                                                            0.1533
# total_de_creditos_directos_de_la_banca_multiple                                     -0.2946
# total_de_creditos_directos_de_las_cajas_municip...                                  -0.2831
# total_de_creditos_directos_de_las_cajas_rurales                                      0.8300
# total_de_creditos_directos_de_las_entidades_de_...                                  -0.0408
# total_de_depositos_de_la_banca_multiple                                             -0.2685
# total_de_depositos_de_las_cajas_municipales                                         -0.2915
# total_de_depositos_de_las_cajas_rurales                                              1.0000
#
# [162 rows x 162 columns]
