# %%
import unidecode
import numpy as np
import pandas as pd
from pathlib import Path
import os; os.chdir('..')
PATH = Path('data/raw/inen_series')

# %%
# !ls {PATH}
# Out:
# datos10.xlsx  datos2.xlsx  datos4.xlsx	datos6.xlsx  datos8.xlsx
# datos1.xlsx   datos3.xlsx  datos5.xlsx	datos7.xlsx  datos9.xlsx

# %%
def read_data(path):
    df = pd.read_excel(path, skiprows=2)#, skip_footer=9)
    df.columns = [unidecode.unidecode(e.lower().strip()) for e in df.columns]
    n = df[df.ambito == 'Fuente(s):'].reset_index()['index'].iat[0]
    df = df.applymap(lambda x: np.nan if x == '-' or x == '...' else x).iloc[:n-1]
    df.ambito = df.ambito.apply(lambda x: unidecode.unidecode(str(x).strip()))
    df.indicador = df.indicador.apply(lambda x: unidecode.unidecode(x.lower().strip().replace(' ', '_')))
    return df

def read_all(path):
    dfs = [read_data(e) for e in path.iterdir() if e.suffix == '.xlsx']
    df = pd.concat(dfs).loc[:, dfs[0].columns]
    return df

# %%
df = read_all(PATH)
df.head()
# Out:
#      ambito                                          indicador  \
# 0  Amazonas  precio_promedio_pagado_al_productor_de_fibra_d...
# 1  Amazonas  precio_promedio_pagado_al_productor_de_fibra_d...
# 2  Amazonas                      produccion_de_madera_aserrada
# 3  Amazonas                              produccion_de_parquet
# 4  Amazonas                               produccion_de_carbon
#
#                     unidad  1960  1961  1962  1963  1964  1965  1966  ...   \
# 0                Soles/kg.   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1                Soles/kg.   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  Miles de metros cúbicos   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3  Miles de metros cúbicos   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  Miles de metros cúbicos   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#        2008    2009      2010  2011  2012  2013  2014  2015  2016  2017
# 0       NaN     NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN     NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  11463.00  8900.0  10290.85   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      5.79     NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN     NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 61 columns]

# %%
df.to_csv('data/processed/inei_series.csv', index=False)
